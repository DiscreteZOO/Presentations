# %% [markdown]
# <h1>DiscreteZOO</h1>
# <p>Visit our <a href="https://github.com/DiscreteZOO/DiscreteZOO-sage">GitHub</a> for more information on how to use the package.</p>

# %% [markdown]
# <h2>Loading the package</h2>

# %%
import discretezoo
from discretezoo.db import query
from discretezoo.db.query import Asc, Desc
from discretezoo.entities.zoograph import ZooGraph
from discretezoo.entities.cvt import CVTGraph, info
from discretezoo.entities.cvt.fields import *

# %% [markdown]
# <h2>Simple examples</h2>

# %%
G = CVTGraph(10, 3) # CVTGraph object with cached properties returned from the database
G
# Out:
# Petersen graph: cubic vertex-transitive graph on 10 vertices, number 3

# %%
G.is_isomorphic(graphs.PetersenGraph())
# Out:
# True

# %%
G.is_cayley() # Is G a Cayley graph?
# Out:
# False

# %%
H = discretezoo.entities.cvt.CVTGraph(14, 1) # Heawood graph
H
# Out:
# Heawood graph: cubic vertex-transitive graph on 14 vertices, number 1

# %%
H.is_cayley()
# Out:
# True

# %% [markdown]
# <h2>Counting</h2>

# %%
info.count() # Number of graphs in CVT repository
# Out:
# 111705

# %%
info.count(diameter == 5) # The number of CVT graphs with diameter 5
# Out:
# 37

# %%
info.count(diameter == 5, groupby = girth) # The number of CVT graphs with diameter 5 broken down by girth
# Out:
# {3: 1, 4: 7, 5: 2, 6: 18, 7: 3, 8: 3, 9: 3}

# %%
info.count(order <= 100, groupby = [girth, diameter]) # The number of CVT graphs for each (girth, diameter) pair
# Out:
# ('graph.girth',
#  {1: ('graph.diameter', {1: 1}),
#   2: ('graph.diameter', {1: 1, 2: 1, 3: 1, 8: 1, 16: 1}),
#   3: ('graph.diameter',
#    {None: 11, 1: 1, 2: 1, 3: 1, 4: 1, 5: 1, 6: 2, 8: 4, 9: 2, 10: 3}),
#   4: ('graph.diameter',
#    {None: 17,
#     2: 2,
#     3: 5,
#     4: 7,
#     5: 7,
#     6: 10,
#     7: 18,
#     8: 16,
#     9: 19,
#     10: 15,
#     11: 8,
#     12: 8,
#     13: 7,
#     14: 6,
#     15: 5,
#     16: 5,
#     17: 5,
#     18: 5,
#     19: 5,
#     20: 5,
#     21: 5,
#     22: 5,
#     23: 5,
#     24: 5,
#     25: 5,
#     26: 1}),
#   5: ('graph.diameter', {None: 2, 2: 1, 5: 2, 6: 3, 7: 2, 9: 1}),
#   6: ('graph.diameter',
#    {None: 3,
#     3: 1,
#     4: 6,
#     5: 18,
#     6: 28,
#     7: 47,
#     8: 55,
#     9: 76,
#     10: 42,
#     11: 25,
#     12: 17,
#     13: 12,
#     14: 8,
#     15: 5,
#     16: 5,
#     17: 3,
#     18: 1}),
#   7: ('graph.diameter', {4: 2, 5: 3, 6: 2, 7: 2, 8: 2, 10: 1, 11: 1, 13: 1}),
#   8: ('graph.diameter', {4: 1, 5: 3, 6: 18, 7: 27, 8: 25, 9: 6, 10: 2}),
#   9: ('graph.diameter', {5: 3}),
#   10: ('graph.diameter', {7: 3, 8: 4})})

# %%
info.count(order < 500, ~is_cayley) # The number of CVT graphs of order less than 500 which are not Cayley graphs
# Out:
# 403

# %%
info.count(girth + diameter == 10) # The number of CVT graphs whose girth and diameter sum to 10
# Out:
# 19

# %%
info.count((girth == 8) | (diameter == 10)) # The number of CVT graphs with girth 8 or diameter 10
# Out:
# 14450

# %% [markdown]
# <h2>Iterating</h2>

# %%
gen = info.all(girth == 5, orderby = Desc(order)) # CVT graphs with girth 5 ordered by their order
next(gen)
# Out:
# Cubic vertex-transitive graph on 1280 vertices, number 2591 (use the .plot() method to plot)

# %%
next(gen).plot()
# Out:
# Graphics object consisting of 3126 graphics primitives

# %%
# both simple CVT graphs with the order equal to the sum of girth and diameter
F1, F2 = info.all(girth + diameter == order, ~has_loops, ~has_multiple_edges)
(F1, F2)
# Out:
# (Tetrahedron: cubic vertex-transitive graph on 4 vertices, number 1,
#  Utility graph: cubic vertex-transitive graph on 6 vertices, number 2)

# %%
# The list of all CVT graphs of diameter 6, sorted first by descending girth and then by ascending order
L = list(info.all(diameter == 6, orderby = [Desc(girth), order]))
L[0].plot()
# Out:
# Graphics object consisting of 101 graphics primitives

# %%
len(L)
# Out:
# 63

# %%
L[1].girth()
# Out:
# 8

# %%
info.one(order == 288, orderby = Desc(girth)).plot() # A CVT graph of order 288 with largest girth
# Out:
# Graphics object consisting of 721 graphics primitives

# %%
info.one(order == 288, orderby = Desc(girth), offset = 1) # A second such graph
# Out:
# Cubic vertex-transitive graph on 288 vertices, number 182 (use the .plot() method to plot)

# %%
info.one(girth >= 6, diameter == 4).plot() # A graph with girth at least 6 and diameter 4
# Out:
# Graphics object consisting of 41 graphics primitives

# %%
info.one(girth >= 6, diameter < 0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-b08c691394d0> in <module>()
# ----> 1 info.one(girth >= Integer(6), diameter < Integer(0))
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zooentity/zooentity.pyc in one(self, *largs, **kargs)
#     868         r = cur.fetchone()
#     869         if r is None:
# --> 870             raise KeyError(largs, kargs)
#     871         return self.cl(todict(r, db), db = db)
#     872
#
# KeyError: ((<<class 'discretezoo.db.query.GreaterEqual'> ((graph.girth) >= (6)) at 0x7f26578c>, <<class 'discretezoo.db.query.LessThan'> ((graph.diameter) < (0)) at 0x7f26504c>), {'limit': 1})

# %%
list(info.all(order == 1300, ~has_loops, ~has_multiple_edges))
# Out:
# [Cubic symmetric graph on 1300 vertices, number 1,
#  Cubic vertex-transitive graph on 1300 vertices]

# %% [markdown]
# ## Fetching only the properties

# %%
L = list(info.props(~is_cayley, girth == 13)) # the data on non-Cayley CVT graphs with girth 13
[{k: v for k, v in d.items() if k != 'data'} for d in L]
# Out:
# [{'average_degree': 3.00000000000000,
#   'clique_number': 2,
#   'connected_components_number': 1,
#   'cvt_index': 104,
#   'diameter': 9,
#   'girth': 13,
#   'has_multiple_edges': 0,
#   'is_arc_transitive': 0,
#   'is_bipartite': 0,
#   'is_cayley': 0,
#   'is_distance_regular': 0,
#   'is_distance_transitive': 0,
#   'is_edge_transitive': 0,
#   'is_eulerian': 0,
#   'is_forest': 0,
#   'is_hamiltonian': 1,
#   'is_moebius_ladder': 0,
#   'is_overfull': 0,
#   'is_partial_cube': 0,
#   'is_prism': 0,
#   'is_regular': 1,
#   'is_split': 0,
#   'is_spx': 0,
#   'is_strongly_regular': 0,
#   'is_tree': 0,
#   'is_vertex_transitive': 1,
#   'number_of_loops': 0,
#   'odd_girth': 13,
#   'order': 546,
#   'size': 819,
#   'triangles_count': 0,
#   'zooid': 19428},
#  {'average_degree': 3.00000000000000,
#   'clique_number': 2,
#   'connected_components_number': 1,
#   'cvt_index': 547,
#   'diameter': 11,
#   'girth': 13,
#   'has_multiple_edges': 0,
#   'is_arc_transitive': 0,
#   'is_bipartite': 0,
#   'is_cayley': 0,
#   'is_distance_regular': 0,
#   'is_distance_transitive': 0,
#   'is_edge_transitive': 0,
#   'is_eulerian': 0,
#   'is_forest': 0,
#   'is_hamiltonian': 1,
#   'is_moebius_ladder': 0,
#   'is_overfull': 0,
#   'is_partial_cube': 0,
#   'is_prism': 0,
#   'is_regular': 1,
#   'is_split': 0,
#   'is_spx': 0,
#   'is_strongly_regular': 0,
#   'is_tree': 0,
#   'is_vertex_transitive': 1,
#   'number_of_loops': 0,
#   'odd_girth': 13,
#   'order': 800,
#   'size': 1200,
#   'triangles_count': 0,
#   'zooid': 43205},
#  {'average_degree': 3.00000000000000,
#   'clique_number': 2,
#   'connected_components_number': 1,
#   'cvt_index': 523,
#   'diameter': 14,
#   'girth': 13,
#   'has_multiple_edges': 0,
#   'is_arc_transitive': 0,
#   'is_bipartite': 0,
#   'is_cayley': 0,
#   'is_distance_regular': 0,
#   'is_distance_transitive': 0,
#   'is_edge_transitive': 0,
#   'is_eulerian': 0,
#   'is_forest': 0,
#   'is_hamiltonian': 1,
#   'is_moebius_ladder': 0,
#   'is_overfull': 0,
#   'is_partial_cube': 0,
#   'is_prism': 0,
#   'is_regular': 1,
#   'is_split': 0,
#   'is_spx': 0,
#   'is_strongly_regular': 0,
#   'is_tree': 0,
#   'is_vertex_transitive': 1,
#   'number_of_loops': 0,
#   'odd_girth': 13,
#   'order': 1092,
#   'size': 1638,
#   'triangles_count': 0,
#   'zooid': 80773}]

# %%
L[0]['data']
# Out:
# ':~?Ga_q@aBgFGN_]`CAACGGgJ?Z_m@iBkFGLOZ_c@QAWDWG?P`]AuDsEGKop`dB[CCGWVOl`fBQFwD_WOV@^AWEkHoZO]@P@{DKE_YoZ@l@YAwPw]o}`nBaHwRWfPT?SBu@WNgC_z_OBqAOMWH_y_[@q@wFWI?W_i@e@_TGE`R_]DE@oSgIOT_KEM?wXGAOD_P?cLKBgFoB_D?Y?{@gBoK_Z?K?c?_AoK?`?sAK@?GOD?bEmLcXwsQACBGAN{GGOpPadAUCc[WxPsbfC}ICSwiPnb`CmHcQWdPLa\\@}BsGgPplb\\IKSKgg?oI_V?m@S?W?oR_d?M?SAGCq{BKIUKghXOamdCI}JW^Wm@}b?IiJwiweaoa[JEHWhgeAf`}FeG?]gc`taSFYEwUW[@YbUJaL_mWfaya_JmS_mHPaxbeJiM_mwsaubSJ]IGlGhAtaeJMI_kgaavaKJYH?lGbatbaJmMOmgqATbEHYNWew}A[aEH]G_eHKamcsI}QwjHKAlcaIaQOiXHaocgJERGihLAjbAHuKOfgmaGa{G]RwmHOAxcMJIP?kxEaqc[JMQ?dXFaUcIGeOoagVoo`vBqEKKgUombNEaFKMg_pAdFIQSshxUcMdWO}I{UGipU`jBYOX@hACFcAOaOPAWXcL`gOqLkZgzpwb}OQO@@W]o}dBIIL{[HSQhdkQMUxGhYCSdiPUQXCHICPcUOAP`?XBCAcIOMPPDhCcVcyQARpGXDqKcYRuPpNHFqOI@HC`ScaDqZcxH{bCgAKsghQSagdPYRSfIXQqdhRiTDIhUSmO[`H?qAb~GADSIw}Pz`NAYDCIW}p}`XUS[w{HrBpfoSa^HQX]BMdyK}[HRhoDNe{TAZxSXeD[eYTuXPUHddXeOTiXHUx~D_f}UE]hVxyD]eKUIWxWhad_eGUEYpUHjdXicUMiXXIidcigUMipWyjdcfIOI[`?x^CCd}OUWXBX`CKe?RIWHKxpC[fEPu]PJhxcnfkOi]xAx}CWfyPe\\`AHucHf[O]\\x@hsC?fQOE\\PExtcYhgSuehRIGDJgaSiY`ChicResPYZXDxmCgeyQeYHBhgCNecPQYXDXkCeeqQ]^PLh|cvhqTYf@Ty\\DQhuTMe@TIWdTi?TigHUy^D[h}TufhVi]D^hEQQcPHYOCihAQmbxJYNCkiCSUgXPIbTFMFYsw\\jbaUPKlXGql`RMuEK|W[r|aBOTfKnU_rDbbQuLLLXKtddBTt|LHVws\\arMUKKvWcuLabXThL^UguDXRXteLhWKul`BZT~LrW?vT_RZuALpUkp|ZBGTmLDUssLmr`U{MBU{rL[BLTtLPVWs|]RStyLTVGvl[R^TrL~VOwD\\q|twJx[k|TrBsvIM^[cyDsrnVSMz\\[{luBrVZNH\\o{\\rbwvLNd]C||wbwVPNN\\G|DprxvGNh\\c|dubtv_NZ\\{|tpRivEMl^S~L|b|VvNv^_~d~s?w?OD_T@U@cCwBOP_P?|~cDv|OX`@A]BsIWPOl`HAmBSKWMOn?@BYFG?GXOz?@BQFn'

# %% [markdown]
# ## Recognizing a graph

# %%
K33 = CVTGraph(list(cartesian_product([(1, 2, 3), ('a', 'b', 'c')])))
K33
# Out:
# Utility graph: cubic vertex-transitive graph on 6 vertices, number 2

# %%
Graph(list(cartesian_product([(1, 2, 3), ('a', 'b', 'c')])))
# Out:
# Graph on 6 vertices

# %%
K34 = CVTGraph(list(cartesian_product([(1, 2, 3), ('a', 'b', 'c', 'd')])))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-37-47971ba5b84a> in <module>()
# ----> 1 K34 = CVTGraph(list(cartesian_product([(Integer(1), Integer(2), Integer(3)), ('a', 'b', 'c', 'd')])))
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/cvt/cvtgraph.pyc in __init__(self, data, cvt_index, symcubic_index, **kargs)
#      72                                    "symcubic_index": symcubic_index},
#      73                          setProp = {"cvt_index": "cvt_index",
# ---> 74                                     "symcubic_index": "symcubic_index"})
#      75
#      76     def _parse_params(self, d):
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zooentity/zooentity.pyc in _init_(self, cl, d, defNone, defVal, setVal, setProp)
#     113             self._init_params(d)
#     114         self._init_props(cl)
# --> 115         cl._init_object(self, cl, d, setProp)
#     116         if self._zooid is not False and d["write"][cl]:
#     117             self._compute_props(cl, d, setProp)
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zoograph/zoograph.pyc in _init_object(self, cl, d, setProp)
#     156         else:
#     157             self._apply_props(cl, d)
# --> 158         cl._construct_object(self, cl, d)
#     159
#     160     def _init_graph(self, cl, d, setProp = {}):
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/cvt/cvtgraph.pyc in _construct_object(self, cl, d)
#     111                 except KeyError:
#     112                     pass
# --> 113         VTGraph.__init__(self, **d)
#     114
#     115         if d["order"] is not None:
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/vt/vtgraph.pyc in __init__(self, data, vt_index, **kargs)
#      56                          defNone = ["order"],
#      57                          setVal = {"data": data, "vt_index": vt_index},
# ---> 58                          setProp = {"vt_index": "vt_index"})
#      59
#      60     def _parse_params(self, d):
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zooentity/zooentity.pyc in _init_(self, cl, d, defNone, defVal, setVal, setProp)
#     115         cl._init_object(self, cl, d, setProp)
#     116         if self._zooid is not False and d["write"][cl]:
# --> 117             self._compute_props(cl, d, setProp)
#     118             self._db_write(cl, d["cur"])
#     119         if self.__class__ is cl and d["commit"]:
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zoograph/zoograph.pyc in _compute_props(self, cl, d, setProp)
#     224           parameters they should take their value from (default: ``{}``).
#     225         """
# --> 226         ZooObject._compute_props(self, cl, d, setProp)
#     227         if cl is ZooGraph:
#     228             for k in ["diameter", "girth"]:
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zooentity/zooentity.pyc in _compute_props(self, cl, d, setProp)
#     374           parameters they should take their value from (default: ``{}``).
#     375         """
# --> 376         cl._check_conditions(self, cl, d)
#     377         self._default_props(cl)
#     378         p = self._getprops(cl)
#
# /home/janos/sage/local/lib/python2.7/site-packages/discretezoo/entities/zooentity/zooentity.pyc in _check_conditions(self, cl, d)
#     398             for k, v in m.items():
#     399                 assert self.__getattribute__(k)(store = (c is not cl)) == v, \
# --> 400                     "Attribute %s does not have value %s" % (k, v)
#     401
#     402     def _db_read(self, cl, join = None, query = None, cur = None,
#
# AssertionError: Attribute is_vertex_transitive does not have value True

# %%
K34 = ZooGraph(list(cartesian_product([(1, 2, 3), ('a', 'b', 'c', 'd')])))
K34
# Out:
# K3,4: graph on 7 vertices

# %%
K34._graphprops
# Out:
# {'average_degree': 3.42857142857000,
#  'connected_components_number': 1,
#  'diameter': 2,
#  'girth': 4,
#  'has_multiple_edges': False,
#  'is_bipartite': True,
#  'is_eulerian': False,
#  'is_forest': False,
#  'is_planar': False,
#  'is_tree': False,
#  'is_vertex_transitive': False,
#  'name': 'K3,4',
#  'number_of_loops': 0,
#  'order': 7,
#  'size': 12}

# %%
K34.is_planar()
# Out:
# False

# %% [markdown]
# <h2>A real life example</h2>

# %%
partial_cubes = list(info.all(is_partial_cube, ~is_prism))

# %%
for graph in partial_cubes:
    print graph
    graph.show()
# Out:
# Desargues graph
# Graphics object consisting of 51 graphics primitives
# Truncated Octahedron
# Graphics object consisting of 61 graphics primitives
# Truncated Cuboctahedron
# Graphics object consisting of 121 graphics primitives
# Truncated Icosidodecahedron
# Graphics object consisting of 301 graphics primitives

# %%
G = partial_cubes[2]
G
# Out:
# Truncated Cuboctahedron: cubic vertex-transitive graph on 48 vertices, number 29 (use the .plot() method to plot)

# %%
G.is_partial_cube() # precomputed property
# Out:
# True

# %%
G.is_partial_cube(certificate = True) # certificate requested, will compute
# Out:
# (True,
#  {0: '000000000',
#   1: '111111111',
#   2: '111111101',
#   3: '111111011',
#   4: '110111111',
#   5: '111111001',
#   6: '111101101',
#   7: '110111110',
#   8: '111111010',
#   9: '010111111',
#   10: '010111110',
#   11: '111001101',
#   12: '111011001',
#   13: '110111010',
#   14: '101111010',
#   15: '010101111',
#   16: '011101101',
#   17: '010110110',
#   18: '011001101',
#   19: '111001001',
#   20: '100111010',
#   21: '010101101',
#   22: '010100111',
#   23: '101011001',
#   24: '101011010',
#   25: '010100110',
#   26: '101001001',
#   27: '101011000',
#   28: '010100101',
#   29: '000110110',
#   30: '011000101',
#   31: '101010010',
#   32: '100110010',
#   33: '000100110',
#   34: '000110010',
#   35: '100010010',
#   36: '010000101',
#   37: '101010000',
#   38: '001000101',
#   39: '101000001',
#   40: '001000001',
#   41: '000000101',
#   42: '101000000',
#   43: '000010010',
#   44: '000000110',
#   45: '000000100',
#   46: '000000010',
#   47: '001000000'})

# %%
G._graphprops

# %%
G.is_planar()

# %%
type(G)

# %%
K33.alias()
# Out:
# {K3,3, Utility graph}

# %% [markdown]
# ## Connecting to a PostgreSQL database

# %%
discretezoo.DEFAULT_DB
# Out:
# <database object at 0x84c81bec: SQLite database in /home/janos/.discretezoo/discretezoo.db>

# %% [markdown]
# To use a PostgreSQL database, the `psycopg2` package for Python must be installed by
# ```bash
# sage -pip install psycopg2
# ```

# %%
import discretezoo.db.postgresql
import auth
discretezoo.DEFAULT_DB = discretezoo.db.postgresql.PostgreSQLDB(auth)

# %%
discretezoo.DEFAULT_DB = discretezoo.db.sqlite.SQLiteDB()

# %%
G = CVTGraph(10, 3)
G.show()
G._db
# Out:
# Graphics object consisting of 26 graphics primitives
# <database object at 0x7eb3294c: PostgreSQL database "discretezoo" at janos@baza.fmf.uni-lj.si>

# %%
info.count(diameter == 3, girth == 5)
# Out:
# 0

# %%
from discretezoo.entities.zoograph import info as zg_info

# %%
zg_info.count()
# Out:
# 212702
